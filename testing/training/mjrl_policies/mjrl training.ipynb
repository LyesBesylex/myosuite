# %%
import warnings
warnings.filterwarnings('ignore')

import gym
from mjrl.utils.gym_env import GymEnv
from mjrl.policies.gaussian_mlp import MLP
from mjrl.baselines.mlp_baseline import MLPBaseline
from mjrl.algos.ppo_clip import PPO
from mjrl.utils.train_agent import train_agent
import myosuite

env = gym.make('ArmReachFixed-v0')

env.reset()

policy_size = (32, 32)
vf_hidden_size = (128, 128)
seed = 123
rl_step_size = 0.1
e = GymEnv(env)

policy = MLP(e.spec, hidden_sizes=policy_size, seed=seed, init_log_std=-0.25, min_log_std=-1.0)

baseline = MLPBaseline(e.spec, reg_coef=1e-3, batch_size=64, hidden_sizes=vf_hidden_size, \
                    epochs=5, learn_rate=1e-3)

agent = PPO(e, policy, baseline, normalized_step_size=rl_step_size, \
            seed=seed, save_logs=True, tensorboard_log="./ppo_objhold_tensorboard/")

print("========================================")
print("Starting policy learning")
print("========================================")

train_agent(job_name='.',
            agent=agent,
            seed=seed,
            niter=400,
            gamma=0.995,
            gae_lambda=0.97,
            sample_mode="trajectories",
            num_traj=96,
            num_samples=0,
            save_freq=100,
            evaluation_rollouts=10)

print("========================================")
print("Job Finished.")
print("========================================")
# Out:
# MyoSuite:> Registering Myo Envs
#     MyoSuite: A contact-rich simulation suite for musculoskeletal motor control
#         Vittorio Caggiano, Huawei Wang, Guillaume Durandau, Massimo Sartori, Vikash Kumar
#         L4DC-2019 | https://sites.google.com/view/myosuite
#
# ========================================
# Starting policy learning
# ========================================
# Reading: logs\log.csv
# Log read from logs\log.csv: had 400 entries
# Loaded last saved iteration: 300
# Resuming from an existing job folder ...
# ......................................................................................
# ITERATION : 301
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:18 2024 ]  301 -398.60 -444.47 -100000000.00
# ------------------  -------------
# VF_error_after         0.00326685
# VF_error_before        0.00337235
# env_samples         1056
# eval_score          -444.472
# eval_success           0
# iteration            300
# kl_dist                0
# num_samples         1056
# rollout_success        0
# running_score       -398.602
# rwd_dense             -2.65438
# rwd_sparse            -3.62007
# stoc_pol_max        -246.71
# stoc_pol_mean       -398.602
# stoc_pol_min        -574.001
# stoc_pol_std          92.0569
# success_percentage     0
# surr_improvement       0
# t_opt                  0.379348
# time_VF                0.18807
# time_sampling          2.31271
# ------------------  -------------
# ......................................................................................
# ITERATION : 302
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:21 2024 ]  302 -402.22 -444.47 -398.60
# ------------------  -------------
# VF_error_after         0.00353264
# VF_error_before        0.00359458
# env_samples         2112
# eval_score          -444.472
# eval_success           0
# iteration            300
# kl_dist                0
# num_samples         1056
# rollout_success        0
# running_score       -398.964
# rwd_dense             -2.67983
# rwd_sparse            -3.65479
# stoc_pol_max        -235.897
# stoc_pol_mean       -402.219
# stoc_pol_min        -568.7
# stoc_pol_std          90.711
# success_percentage     0
# surr_improvement       0
# t_opt                  0.287165
# time_VF                0.122937
# time_sampling          2.2143
# ------------------  -------------
# ......................................................................................
# ITERATION : 303
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:25 2024 ]  303 -411.29 -444.47 -398.60
# ------------------  -------------
# VF_error_after         0.00334299
# VF_error_before        0.00344299
# env_samples         3168
# eval_score          -444.472
# eval_success           0
# iteration            300
# kl_dist                0
# num_samples         1056
# rollout_success        0
# running_score       -400.196
# rwd_dense             -2.74023
# rwd_sparse            -3.73715
# stoc_pol_max        -237.949
# stoc_pol_mean       -411.287
# stoc_pol_min        -564.707
# stoc_pol_std          95.5898
# success_percentage     0
# surr_improvement       0
# t_opt                  0.286123
# time_VF                0.132402
# time_sampling          2.15104
# ------------------  -------------
# ......................................................................................
# ITERATION : 304
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:28 2024 ]  304 -412.85 -444.47 -398.60
# ------------------  -------------
# VF_error_after         0.00265917
# VF_error_before        0.00273487
# env_samples         4224
# eval_score          -444.472
# eval_success           0
# iteration            300
# kl_dist                0
# num_samples         1056
# rollout_success        0
# running_score       -401.461
# rwd_dense             -2.7507
# rwd_sparse            -3.75142
# stoc_pol_max        -244.485
# stoc_pol_mean       -412.845
# stoc_pol_min        -572.9
# stoc_pol_std          91.6029
# success_percentage     0
# surr_improvement       0
# t_opt                  0.270824
# time_VF                0.126327
# time_sampling          2.11337
# ------------------  -------------
# ......................................................................................
# ITERATION : 305
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:31 2024 ]  305 -415.88 -444.47 -398.60
# ------------------  -------------
# VF_error_after         0.00289486
# VF_error_before        0.0029444
# env_samples         5280
# eval_score          -444.472
# eval_success           0
# iteration            300
# kl_dist                0
# num_samples         1056
# rollout_success        0
# running_score       -402.903
# rwd_dense             -2.77018
# rwd_sparse            -3.77798
# stoc_pol_max        -232.248
# stoc_pol_mean       -415.879
# stoc_pol_min        -581.961
# stoc_pol_std          91.335
# success_percentage     0
# surr_improvement       0
# t_opt                  0.294202
# time_VF                0.126761
# time_sampling          2.1148
# ------------------  -------------
# ......................................................................................
# ITERATION : 306
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:35 2024 ]  306 -405.24 -444.47 -398.60
# ------------------  -------------
# VF_error_after         0.00318038
# VF_error_before        0.00333041
# env_samples         6336
# eval_score          -444.472
# eval_success           0
# iteration            300
# kl_dist                0
# num_samples         1056
# rollout_success        0
# running_score       -403.137
# rwd_dense             -2.69909
# rwd_sparse            -3.68104
# stoc_pol_max        -236.72
# stoc_pol_mean       -405.242
# stoc_pol_min        -578.199
# stoc_pol_std          90.7992
# success_percentage     0
# surr_improvement       0
# t_opt                  0.264136
# time_VF                0.1274
# time_sampling          2.15436
# ------------------  -------------
# ......................................................................................
# ITERATION : 307
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:38 2024 ]  307 -388.51 -444.47 -398.60
# ------------------  -------------
# VF_error_after         0.00365626
# VF_error_before        0.00371646
# env_samples         7392
# eval_score          -444.472
# eval_success           0
# iteration            300
# kl_dist                0
# num_samples         1056
# rollout_success        0
# running_score       -401.674
# rwd_dense             -2.58874
# rwd_sparse            -3.53057
# stoc_pol_max        -223.638
# stoc_pol_mean       -388.511
# stoc_pol_min        -570.6
# stoc_pol_std          87.8489
# success_percentage     0
# surr_improvement       0
# t_opt                  0.260811
# time_VF                0.122178
# time_sampling          2.0786
# ------------------  -------------
# ......................................................................................
# ITERATION : 308
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:41 2024 ]  308 -411.62 -444.47 -388.51
# ------------------  -------------
# VF_error_after         0.0028039
# VF_error_before        0.00287091
# env_samples         8448
# eval_score          -444.472
# eval_success           0
# iteration            300
# kl_dist                0
# num_samples         1056
# rollout_success        0
# running_score       -402.669
# rwd_dense             -2.74115
# rwd_sparse            -3.7384
# stoc_pol_max        -238.967
# stoc_pol_mean       -411.622
# stoc_pol_min        -566.062
# stoc_pol_std          89.5575
# success_percentage     0
# surr_improvement       0
# t_opt                  0.272637
# time_VF                0.209632
# time_sampling          2.09197
# ------------------  -------------
# ......................................................................................
# ITERATION : 309
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:45 2024 ]  309 -414.21 -444.47 -388.51
# ------------------  -------------
# VF_error_after         0.0024638
# VF_error_before        0.00255328
# env_samples         9504
# eval_score          -444.472
# eval_success           0
# iteration            300
# kl_dist                0
# num_samples         1056
# rollout_success        0
# running_score       -403.823
# rwd_dense             -2.75933
# rwd_sparse            -3.76319
# stoc_pol_max        -242.265
# stoc_pol_mean       -414.209
# stoc_pol_min        -584.684
# stoc_pol_std          83.0048
# success_percentage     0
# surr_improvement       0
# t_opt                  0.264275
# time_VF                0.120594
# time_sampling          2.11305
# ------------------  -------------
# ......................................................................................
# ITERATION : 310
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:48 2024 ]  310 -391.65 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00356225
# VF_error_before         0.00370947
# env_samples         10560
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -402.606
# rwd_dense              -2.6083
# rwd_sparse             -3.55724
# stoc_pol_max         -224.415
# stoc_pol_mean        -391.654
# stoc_pol_min         -575.39
# stoc_pol_std           94.3422
# success_percentage      0
# surr_improvement        0
# t_opt                   0.292783
# time_VF                 0.122772
# time_sampling           2.14098
# ------------------  --------------
# ......................................................................................
# ITERATION : 311
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:52 2024 ]  311 -431.17 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00254713
# VF_error_before         0.00262091
# env_samples         11616
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -405.463
# rwd_dense              -2.87282
# rwd_sparse             -3.91795
# stoc_pol_max         -229.972
# stoc_pol_mean        -431.168
# stoc_pol_min         -587.658
# stoc_pol_std           93.1268
# success_percentage      0
# surr_improvement        0
# t_opt                   0.321452
# time_VF                 0.162732
# time_sampling           2.11665
# ------------------  --------------
# ......................................................................................
# ITERATION : 312
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:55 2024 ]  312 -399.03 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00297419
# VF_error_before         0.00305969
# env_samples         12672
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -404.819
# rwd_dense              -2.6587
# rwd_sparse             -3.62597
# stoc_pol_max         -253.275
# stoc_pol_mean        -399.026
# stoc_pol_min         -559.965
# stoc_pol_std           95.6379
# success_percentage      0
# surr_improvement        0
# t_opt                   0.266635
# time_VF                 0.129051
# time_sampling           2.11773
# ------------------  --------------
# ......................................................................................
# ITERATION : 313
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:47:58 2024 ]  313 -392.04 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00289315
# VF_error_before         0.00295942
# env_samples         13728
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -403.541
# rwd_dense              -2.61159
# rwd_sparse             -3.56172
# stoc_pol_max         -227.096
# stoc_pol_mean        -392.037
# stoc_pol_min         -581.219
# stoc_pol_std           95.9376
# success_percentage      0
# surr_improvement        0
# t_opt                   0.282728
# time_VF                 0.126909
# time_sampling           2.10233
# ------------------  --------------
# ......................................................................................
# ITERATION : 314
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:01 2024 ]  314 -413.69 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00236913
# VF_error_before         0.00271234
# env_samples         14784
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -404.555
# rwd_dense              -2.75629
# rwd_sparse             -3.75904
# stoc_pol_max         -237.611
# stoc_pol_mean        -413.687
# stoc_pol_min         -566.826
# stoc_pol_std           84.1701
# success_percentage      0
# surr_improvement        0
# t_opt                   0.290284
# time_VF                 0.13822
# time_sampling           2.10183
# ------------------  --------------
# ......................................................................................
# ITERATION : 315
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:05 2024 ]  315 -412.32 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00264006
# VF_error_before         0.00270109
# env_samples         15840
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -405.332
# rwd_dense              -2.74584
# rwd_sparse             -3.7448
# stoc_pol_max         -247.446
# stoc_pol_mean        -412.324
# stoc_pol_min         -554.907
# stoc_pol_std           91.9249
# success_percentage      0
# surr_improvement        0
# t_opt                   0.269646
# time_VF                 0.129867
# time_sampling           2.09113
# ------------------  --------------
# ......................................................................................
# ITERATION : 316
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:08 2024 ]  316 -412.00 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00253538
# VF_error_before         0.00260507
# env_samples         16896
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -405.999
# rwd_dense              -2.7445
# rwd_sparse             -3.74297
# stoc_pol_max         -243.421
# stoc_pol_mean        -412.003
# stoc_pol_min         -568.192
# stoc_pol_std           93.5263
# success_percentage      0
# surr_improvement        0
# t_opt                   0.266644
# time_VF                 0.122308
# time_sampling           2.09813
# ------------------  --------------
# ......................................................................................
# ITERATION : 317
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:11 2024 ]  317 -407.36 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00249318
# VF_error_before         0.00263005
# env_samples         17952
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -406.135
# rwd_dense              -2.71326
# rwd_sparse             -3.70037
# stoc_pol_max         -234.104
# stoc_pol_mean        -407.36
# stoc_pol_min         -561.801
# stoc_pol_std           84.0022
# success_percentage      0
# surr_improvement        0
# t_opt                   0.261013
# time_VF                 0.124271
# time_sampling           2.06636
# ------------------  --------------
# ......................................................................................
# ITERATION : 318
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:14 2024 ]  318 -408.41 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00247555
# VF_error_before         0.00256291
# env_samples         19008
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -406.363
# rwd_dense              -2.72036
# rwd_sparse             -3.71005
# stoc_pol_max         -270.236
# stoc_pol_mean        -408.414
# stoc_pol_min         -596.678
# stoc_pol_std           86.591
# success_percentage      0
# surr_improvement        0
# t_opt                   0.272572
# time_VF                 0.124541
# time_sampling           2.10811
# ------------------  --------------
# ......................................................................................
# ITERATION : 319
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:18 2024 ]  319 -400.89 -444.47 -388.51
# ------------------  -------------
# VF_error_after          0.0024457
# VF_error_before         0.0030848
# env_samples         20064
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -405.816
# rwd_dense              -2.67113
# rwd_sparse             -3.64291
# stoc_pol_max         -234.64
# stoc_pol_mean        -400.89
# stoc_pol_min         -580.961
# stoc_pol_std           96.1066
# success_percentage      0
# surr_improvement        0
# t_opt                   0.266078
# time_VF                 0.134061
# time_sampling           2.03315
# ------------------  -------------
# ......................................................................................
# ITERATION : 320
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:21 2024 ]  320 -404.66 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00227599
# VF_error_before         0.00233727
# env_samples         21120
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -405.7
# rwd_dense              -2.69466
# rwd_sparse             -3.67501
# stoc_pol_max         -239.451
# stoc_pol_mean        -404.657
# stoc_pol_min         -557.847
# stoc_pol_std           93.1877
# success_percentage      0
# surr_improvement        0
# t_opt                   0.265335
# time_VF                 0.122561
# time_sampling           2.04403
# ------------------  --------------
# ......................................................................................
# ITERATION : 321
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:24 2024 ]  321 -392.75 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00261485
# VF_error_before         0.00257917
# env_samples         22176
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -404.405
# rwd_dense              -2.61606
# rwd_sparse             -3.56782
# stoc_pol_max         -230.276
# stoc_pol_mean        -392.747
# stoc_pol_min         -561.307
# stoc_pol_std           87.7827
# success_percentage      0
# surr_improvement        0
# t_opt                   0.259916
# time_VF                 0.12031
# time_sampling           2.06
# ------------------  --------------
# ......................................................................................
# ITERATION : 322
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:27 2024 ]  322 -401.65 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00265833
# VF_error_before         0.00286078
# env_samples         23232
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -404.129
# rwd_dense              -2.67526
# rwd_sparse             -3.64854
# stoc_pol_max         -225.965
# stoc_pol_mean        -401.649
# stoc_pol_min         -569.21
# stoc_pol_std           95.6403
# success_percentage      0
# surr_improvement        0
# t_opt                   0.257924
# time_VF                 0.11925
# time_sampling           2.02072
# ------------------  --------------
# ......................................................................................
# ITERATION : 323
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:31 2024 ]  323 -405.13 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00243875
# VF_error_before         0.00248683
# env_samples         24288
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -404.229
# rwd_dense              -2.69777
# rwd_sparse             -3.67924
# stoc_pol_max         -233.938
# stoc_pol_mean        -405.128
# stoc_pol_min         -596.004
# stoc_pol_std           90.744
# success_percentage      0
# surr_improvement        0
# t_opt                   0.303578
# time_VF                 0.127298
# time_sampling           2.12019
# ------------------  --------------
# ......................................................................................
# ITERATION : 324
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:34 2024 ]  324 -398.43 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00251475
# VF_error_before         0.00255916
# env_samples         25344
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -403.649
# rwd_dense              -2.65422
# rwd_sparse             -3.61986
# stoc_pol_max         -225.149
# stoc_pol_mean        -398.43
# stoc_pol_min         -581.277
# stoc_pol_std           87.4207
# success_percentage      0
# surr_improvement        0
# t_opt                   0.27174
# time_VF                 0.123638
# time_sampling           2.12475
# ------------------  --------------
# ......................................................................................
# ITERATION : 325
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:37 2024 ]  325 -401.99 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00244839
# VF_error_before         0.00252851
# env_samples         26400
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -403.483
# rwd_dense              -2.67821
# rwd_sparse             -3.65258
# stoc_pol_max         -228.182
# stoc_pol_mean        -401.985
# stoc_pol_min         -571.855
# stoc_pol_std           96.6204
# success_percentage      0
# surr_improvement        0
# t_opt                   0.262134
# time_VF                 0.122172
# time_sampling           2.05417
# ------------------  --------------
# ......................................................................................
# ITERATION : 326
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:40 2024 ]  326 -404.87 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00225766
# VF_error_before         0.00226181
# env_samples         27456
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -403.621
# rwd_dense              -2.69737
# rwd_sparse             -3.6787
# stoc_pol_max         -232.098
# stoc_pol_mean        -404.867
# stoc_pol_min         -570.503
# stoc_pol_std           96.5583
# success_percentage      0
# surr_improvement        0
# t_opt                   0.30689
# time_VF                 0.125192
# time_sampling           2.07942
# ------------------  --------------
# ......................................................................................
# ITERATION : 327
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:44 2024 ]  327 -414.48 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00187406
# VF_error_before         0.0019135
# env_samples         28512
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -404.707
# rwd_dense              -2.76176
# rwd_sparse             -3.7665
# stoc_pol_max         -245.695
# stoc_pol_mean        -414.482
# stoc_pol_min         -572.407
# stoc_pol_std           89.3922
# success_percentage      0
# surr_improvement        0
# t_opt                   0.298951
# time_VF                 0.128665
# time_sampling           2.07434
# ------------------  --------------
# ......................................................................................
# ITERATION : 328
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:47 2024 ]  328 -404.00 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00218922
# VF_error_before         0.00222289
# env_samples         29568
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -404.636
# rwd_dense              -2.69154
# rwd_sparse             -3.67075
# stoc_pol_max         -228.382
# stoc_pol_mean        -403.996
# stoc_pol_min         -569.471
# stoc_pol_std           86.4401
# success_percentage      0
# surr_improvement        0
# t_opt                   0.293143
# time_VF                 0.131258
# time_sampling           2.10009
# ------------------  --------------
# ......................................................................................
# ITERATION : 329
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:50 2024 ]  329 -416.68 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00220105
# VF_error_before         0.00223918
# env_samples         30624
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -405.84
# rwd_dense              -2.77498
# rwd_sparse             -3.78453
# stoc_pol_max         -241.581
# stoc_pol_mean        -416.68
# stoc_pol_min         -587.065
# stoc_pol_std           87.5998
# success_percentage      0
# surr_improvement        0
# t_opt                   0.274364
# time_VF                 0.130192
# time_sampling           2.05755
# ------------------  --------------
# ......................................................................................
# ITERATION : 330
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:54 2024 ]  330 -407.57 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.0017212
# VF_error_before         0.00188841
# env_samples         31680
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -406.014
# rwd_dense              -2.7144
# rwd_sparse             -3.70192
# stoc_pol_max         -266.35
# stoc_pol_mean        -407.574
# stoc_pol_min         -582.035
# stoc_pol_std           87.3015
# success_percentage      0
# surr_improvement        0
# t_opt                   0.273999
# time_VF                 0.131519
# time_sampling           2.06285
# ------------------  --------------
# ......................................................................................
# ITERATION : 331
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:48:57 2024 ]  331 -400.21 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00218397
# VF_error_before         0.00212398
# env_samples         32736
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -405.433
# rwd_dense              -2.66612
# rwd_sparse             -3.63609
# stoc_pol_max         -234.127
# stoc_pol_mean        -400.206
# stoc_pol_min         -573.546
# stoc_pol_std           88.2865
# success_percentage      0
# surr_improvement        0
# t_opt                   0.293498
# time_VF                 0.126326
# time_sampling           2.13602
# ------------------  --------------
# ......................................................................................
# ITERATION : 332
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:00 2024 ]  332 -407.56 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00214798
# VF_error_before         0.00263449
# env_samples         33792
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -405.646
# rwd_dense              -2.71543
# rwd_sparse             -3.70333
# stoc_pol_max         -254.081
# stoc_pol_mean        -407.559
# stoc_pol_min         -563.019
# stoc_pol_std           84.4204
# success_percentage      0
# surr_improvement        0
# t_opt                   0.278376
# time_VF                 0.126065
# time_sampling           2.12007
# ------------------  --------------
# ......................................................................................
# ITERATION : 333
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:04 2024 ]  333 -409.02 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.0022899
# VF_error_before         0.00235124
# env_samples         34848
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -405.983
# rwd_dense              -2.72408
# rwd_sparse             -3.71513
# stoc_pol_max         -230.258
# stoc_pol_mean        -409.018
# stoc_pol_min         -589.301
# stoc_pol_std           97.9105
# success_percentage      0
# surr_improvement        0
# t_opt                   0.369255
# time_VF                 0.159804
# time_sampling           2.48539
# ------------------  --------------
# ......................................................................................
# ITERATION : 334
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:08 2024 ]  334 -415.22 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00204607
# VF_error_before         0.00208537
# env_samples         35904
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -406.907
# rwd_dense              -2.76566
# rwd_sparse             -3.77182
# stoc_pol_max         -241.404
# stoc_pol_mean        -415.222
# stoc_pol_min         -591.562
# stoc_pol_std           96.2722
# success_percentage      0
# surr_improvement        0
# t_opt                   0.342311
# time_VF                 0.155151
# time_sampling           2.63558
# ------------------  --------------
# ......................................................................................
# ITERATION : 335
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:13 2024 ]  335 -405.42 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00216494
# VF_error_before         0.00217411
# env_samples         36960
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -406.758
# rwd_dense              -2.69988
# rwd_sparse             -3.68213
# stoc_pol_max         -241.154
# stoc_pol_mean        -405.42
# stoc_pol_min         -580.032
# stoc_pol_std           93.4862
# success_percentage      0
# surr_improvement        0
# t_opt                   0.433795
# time_VF                 0.15285
# time_sampling           2.62886
# ------------------  --------------
# ......................................................................................
# ITERATION : 336
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:16 2024 ]  336 -418.60 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00183958
# VF_error_before         0.00195787
# env_samples         38016
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.943
# rwd_dense              -2.78879
# rwd_sparse             -3.80337
# stoc_pol_max         -238.898
# stoc_pol_mean        -418.602
# stoc_pol_min         -579.712
# stoc_pol_std           96.4237
# success_percentage      0
# surr_improvement        0
# t_opt                   0.284881
# time_VF                 0.152846
# time_sampling           2.39703
# ------------------  --------------
# ......................................................................................
# ITERATION : 337
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:20 2024 ]  337 -401.10 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00226569
# VF_error_before         0.0023567
# env_samples         39072
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.259
# rwd_dense              -2.67139
# rwd_sparse             -3.64328
# stoc_pol_max         -234.423
# stoc_pol_mean        -401.103
# stoc_pol_min         -570.071
# stoc_pol_std           86.3921
# success_percentage      0
# surr_improvement        0
# t_opt                   0.266278
# time_VF                 0.126151
# time_sampling           2.07006
# ------------------  --------------
# ......................................................................................
# ITERATION : 338
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:23 2024 ]  338 -416.69 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00211194
# VF_error_before         0.00214387
# env_samples         40128
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -408.202
# rwd_dense              -2.77577
# rwd_sparse             -3.78561
# stoc_pol_max         -229.179
# stoc_pol_mean        -416.69
# stoc_pol_min         -578.566
# stoc_pol_std           85.1704
# success_percentage      0
# surr_improvement        0
# t_opt                   0.278118
# time_VF                 0.127975
# time_sampling           2.06082
# ------------------  --------------
# ......................................................................................
# ITERATION : 339
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:26 2024 ]  339 -408.26 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00198613
# VF_error_before         0.00203135
# env_samples         41184
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -408.207
# rwd_dense              -2.71908
# rwd_sparse             -3.70831
# stoc_pol_max         -253.514
# stoc_pol_mean        -408.256
# stoc_pol_min         -569.682
# stoc_pol_std           78.0487
# success_percentage      0
# surr_improvement        0
# t_opt                   0.271266
# time_VF                 0.127178
# time_sampling           2.08916
# ------------------  --------------
# ......................................................................................
# ITERATION : 340
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:29 2024 ]  340 -403.29 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00226772
# VF_error_before         0.00242344
# env_samples         42240
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.715
# rwd_dense              -2.686
# rwd_sparse             -3.66319
# stoc_pol_max         -226.739
# stoc_pol_mean        -403.29
# stoc_pol_min         -571.477
# stoc_pol_std           93.1137
# success_percentage      0
# surr_improvement        0
# t_opt                   0.277922
# time_VF                 0.127233
# time_sampling           2.10715
# ------------------  --------------
# ......................................................................................
# ITERATION : 341
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:33 2024 ]  341 -397.68 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00192307
# VF_error_before         0.00192332
# env_samples         43296
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -406.712
# rwd_dense              -2.6489
# rwd_sparse             -3.6126
# stoc_pol_max         -229.794
# stoc_pol_mean        -397.681
# stoc_pol_min         -588.889
# stoc_pol_std           91.7732
# success_percentage      0
# surr_improvement        0
# t_opt                   0.307412
# time_VF                 0.145097
# time_sampling           2.05301
# ------------------  --------------
# ......................................................................................
# ITERATION : 342
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:36 2024 ]  342 -413.65 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00165388
# VF_error_before         0.00186599
# env_samples         44352
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.406
# rwd_dense              -2.75527
# rwd_sparse             -3.75766
# stoc_pol_max         -258.271
# stoc_pol_mean        -413.651
# stoc_pol_min         -582.408
# stoc_pol_std           85.9548
# success_percentage      0
# surr_improvement        0
# t_opt                   0.2772
# time_VF                 0.121886
# time_sampling           2.05344
# ------------------  --------------
# ......................................................................................
# ITERATION : 343
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:39 2024 ]  343 -425.95 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.0015342
# VF_error_before         0.00179946
# env_samples         45408
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -409.261
# rwd_dense              -2.83821
# rwd_sparse             -3.87075
# stoc_pol_max         -236.78
# stoc_pol_mean        -425.955
# stoc_pol_min         -564.826
# stoc_pol_std           93.117
# success_percentage      0
# surr_improvement        0
# t_opt                   0.264035
# time_VF                 0.124262
# time_sampling           2.02715
# ------------------  --------------
# ......................................................................................
# ITERATION : 344
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:42 2024 ]  344 -404.83 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00174393
# VF_error_before         0.00180626
# env_samples         46464
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -408.818
# rwd_dense              -2.6967
# rwd_sparse             -3.67779
# stoc_pol_max         -244.836
# stoc_pol_mean        -404.831
# stoc_pol_min         -575.947
# stoc_pol_std           88.2377
# success_percentage      0
# surr_improvement        0
# t_opt                   0.268449
# time_VF                 0.126107
# time_sampling           2.04003
# ------------------  --------------
# ......................................................................................
# ITERATION : 345
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:46 2024 ]  345 -402.20 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00211654
# VF_error_before         0.00222044
# env_samples         47520
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -408.156
# rwd_dense              -2.67822
# rwd_sparse             -3.65259
# stoc_pol_max         -228.606
# stoc_pol_mean        -402.204
# stoc_pol_min         -560.176
# stoc_pol_std           89.9659
# success_percentage      0
# surr_improvement        0
# t_opt                   0.283172
# time_VF                 0.131413
# time_sampling           2.08328
# ------------------  --------------
# ......................................................................................
# ITERATION : 346
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:49 2024 ]  346 -407.13 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00180061
# VF_error_before         0.00195902
# env_samples         48576
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -408.054
# rwd_dense              -2.71281
# rwd_sparse             -3.69976
# stoc_pol_max         -246.291
# stoc_pol_mean        -407.129
# stoc_pol_min         -568.467
# stoc_pol_std           90.0498
# success_percentage      0
# surr_improvement        0
# t_opt                   0.269857
# time_VF                 0.1207
# time_sampling           2.03294
# ------------------  --------------
# ......................................................................................
# ITERATION : 347
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:52 2024 ]  347 -407.57 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00164437
# VF_error_before         0.00168391
# env_samples         49632
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -408.005
# rwd_dense              -2.71491
# rwd_sparse             -3.70261
# stoc_pol_max         -237.521
# stoc_pol_mean        -407.57
# stoc_pol_min         -591.707
# stoc_pol_std           90.9631
# success_percentage      0
# surr_improvement        0
# t_opt                   0.303033
# time_VF                 0.126441
# time_sampling           2.03619
# ------------------  --------------
# ......................................................................................
# ITERATION : 348
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:55 2024 ]  348 -398.91 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00202116
# VF_error_before         0.00203987
# env_samples         50688
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.096
# rwd_dense              -2.65643
# rwd_sparse             -3.62287
# stoc_pol_max         -230.844
# stoc_pol_mean        -398.907
# stoc_pol_min         -566.564
# stoc_pol_std           91.4859
# success_percentage      0
# surr_improvement        0
# t_opt                   0.263202
# time_VF                 0.121716
# time_sampling           2.07809
# ------------------  --------------
# ......................................................................................
# ITERATION : 349
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:49:59 2024 ]  349 -411.27 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00189475
# VF_error_before         0.00192476
# env_samples         51744
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.513
# rwd_dense              -2.74003
# rwd_sparse             -3.73687
# stoc_pol_max         -258.703
# stoc_pol_mean        -411.274
# stoc_pol_min         -564.934
# stoc_pol_std           91.1438
# success_percentage      0
# surr_improvement        0
# t_opt                   0.317901
# time_VF                 0.13735
# time_sampling           2.10903
# ------------------  --------------
# ......................................................................................
# ITERATION : 350
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:50:02 2024 ]  350 -400.07 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00189003
# VF_error_before         0.00199544
# env_samples         52800
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -406.769
# rwd_dense              -2.66498
# rwd_sparse             -3.63454
# stoc_pol_max         -230.691
# stoc_pol_mean        -400.071
# stoc_pol_min         -564.949
# stoc_pol_std           92.9451
# success_percentage      0
# surr_improvement        0
# t_opt                   0.286677
# time_VF                 0.132681
# time_sampling           2.14412
# ------------------  --------------
# ......................................................................................
# ITERATION : 351
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:50:06 2024 ]  351 -409.78 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00187351
# VF_error_before         0.0019025
# env_samples         53856
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.07
# rwd_dense              -2.73042
# rwd_sparse             -3.72377
# stoc_pol_max         -234.004
# stoc_pol_mean        -409.777
# stoc_pol_min         -567.678
# stoc_pol_std           92.5576
# success_percentage      0
# surr_improvement        0
# t_opt                   0.380082
# time_VF                 0.181641
# time_sampling           2.76174
# ------------------  --------------
# ......................................................................................
# ITERATION : 352
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:50:10 2024 ]  352 -396.67 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00163922
# VF_error_before         0.00171023
# env_samples         54912
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -406.03
# rwd_dense              -2.64285
# rwd_sparse             -3.60435
# stoc_pol_max         -240.993
# stoc_pol_mean        -396.672
# stoc_pol_min         -578.247
# stoc_pol_std           86.1166
# success_percentage      0
# surr_improvement        0
# t_opt                   0.270824
# time_VF                 0.118607
# time_sampling           2.1261
# ------------------  --------------
# ......................................................................................
# ITERATION : 353
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:50:14 2024 ]  353 -409.04 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00190434
# VF_error_before         0.00197293
# env_samples         55968
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -406.331
# rwd_dense              -2.72432
# rwd_sparse             -3.71545
# stoc_pol_max         -241.028
# stoc_pol_mean        -409.041
# stoc_pol_min         -581.421
# stoc_pol_std           93.3015
# success_percentage      0
# surr_improvement        0
# t_opt                   0.373267
# time_VF                 0.175356
# time_sampling           2.59385
# ------------------  --------------
# ......................................................................................
# ITERATION : 354
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:50:18 2024 ]  354 -430.49 -444.47 -388.51
# ------------------  --------------
# VF_error_after          0.00163553
# VF_error_before         0.00196953
# env_samples         57024
# eval_score           -444.472
# ...
# env_samples         86592
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.301
# rwd_dense              -2.72192
# rwd_sparse             -3.71217
# stoc_pol_max         -243.191
# stoc_pol_mean        -408.496
# stoc_pol_min         -579.007
# stoc_pol_std           97.2486
# success_percentage      0
# surr_improvement        0
# t_opt                   0.288929
# time_VF                 0.130688
# time_sampling           2.26381
# ------------------  --------------
# ......................................................................................
# ITERATION : 383
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:02 2024 ]  383 -395.63 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.00137793
# VF_error_before         0.00137317
# env_samples         87648
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -406.133
# rwd_dense              -2.63438
# rwd_sparse             -3.5928
# stoc_pol_max         -244.626
# stoc_pol_mean        -395.629
# stoc_pol_min         -579.135
# stoc_pol_std           98.8063
# success_percentage      0
# surr_improvement        0
# t_opt                   0.292476
# time_VF                 0.14386
# time_sampling           2.21599
# ------------------  --------------
# ......................................................................................
# ITERATION : 384
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:05 2024 ]  384 -403.69 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.00125533
# VF_error_before         0.00165198
# env_samples         88704
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -405.89
# rwd_dense              -2.68865
# rwd_sparse             -3.66681
# stoc_pol_max         -246.068
# stoc_pol_mean        -403.695
# stoc_pol_min         -570.491
# stoc_pol_std           87.2047
# success_percentage      0
# surr_improvement        0
# t_opt                   0.285739
# time_VF                 0.13304
# time_sampling           2.22856
# ------------------  --------------
# ......................................................................................
# ITERATION : 385
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:09 2024 ]  385 -417.70 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.0014751
# VF_error_before         0.00144995
# env_samples         89760
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.071
# rwd_dense              -2.78174
# rwd_sparse             -3.79375
# stoc_pol_max         -257.356
# stoc_pol_mean        -417.701
# stoc_pol_min         -562.366
# stoc_pol_std           92.1577
# success_percentage      0
# surr_improvement        0
# t_opt                   0.300185
# time_VF                 0.134809
# time_sampling           2.24566
# ------------------  --------------
# ......................................................................................
# ITERATION : 386
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:12 2024 ]  386 -411.54 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.00150266
# VF_error_before         0.00162188
# env_samples         90816
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.517
# rwd_dense              -2.74113
# rwd_sparse             -3.73837
# stoc_pol_max         -237.64
# stoc_pol_mean        -411.535
# stoc_pol_min         -572.231
# stoc_pol_std           93.6616
# success_percentage      0
# surr_improvement        0
# t_opt                   0.333598
# time_VF                 0.143537
# time_sampling           2.40365
# ------------------  --------------
# ......................................................................................
# ITERATION : 387
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:17 2024 ]  387 -405.75 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.00135104
# VF_error_before         0.00134727
# env_samples         91872
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.341
# rwd_dense              -2.70366
# rwd_sparse             -3.68727
# stoc_pol_max         -231.272
# stoc_pol_mean        -405.755
# stoc_pol_min         -563.574
# stoc_pol_std           90.4459
# success_percentage      0
# surr_improvement        0
# t_opt                   0.554902
# time_VF                 0.249833
# time_sampling           2.81755
# ------------------  --------------
# ......................................................................................
# ITERATION : 388
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:21 2024 ]  388 -419.64 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.0012159
# VF_error_before         0.00128306
# env_samples         92928
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -408.571
# rwd_dense              -2.79574
# rwd_sparse             -3.81283
# stoc_pol_max         -238.084
# stoc_pol_mean        -419.645
# stoc_pol_min         -571.765
# stoc_pol_std           88.7978
# success_percentage      0
# surr_improvement        0
# t_opt                   0.327765
# time_VF                 0.138301
# time_sampling           2.47502
# ------------------  --------------
# ......................................................................................
# ITERATION : 389
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:25 2024 ]  389 -404.38 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.00199591
# VF_error_before         0.0019908
# env_samples         93984
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -408.152
# rwd_dense              -2.69411
# rwd_sparse             -3.67425
# stoc_pol_max         -227.933
# stoc_pol_mean        -404.382
# stoc_pol_min         -570.595
# stoc_pol_std           97.0754
# success_percentage      0
# surr_improvement        0
# t_opt                   0.357096
# time_VF                 0.154713
# time_sampling           2.36439
# ------------------  --------------
# ......................................................................................
# ITERATION : 390
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:28 2024 ]  390 -409.81 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.00137432
# VF_error_before         0.00143437
# env_samples         95040
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -408.318
# rwd_dense              -2.73055
# rwd_sparse             -3.72395
# stoc_pol_max         -243.573
# stoc_pol_mean        -409.812
# stoc_pol_min         -573.233
# stoc_pol_std           92.4007
# success_percentage      0
# surr_improvement        0
# t_opt                   0.300229
# time_VF                 0.143751
# time_sampling           2.36835
# ------------------  --------------
# ......................................................................................
# ITERATION : 391
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:32 2024 ]  391 -397.74 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.00171739
# VF_error_before         0.00163554
# env_samples         96096
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.26
# rwd_dense              -2.64956
# rwd_sparse             -3.61351
# stoc_pol_max         -242.396
# stoc_pol_mean        -397.736
# stoc_pol_min         -563.94
# stoc_pol_std           93.1249
# success_percentage      0
# surr_improvement        0
# t_opt                   0.326273
# time_VF                 0.140457
# time_sampling           2.23962
# ------------------  --------------
# ......................................................................................
# ITERATION : 392
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:36 2024 ]  392 -427.86 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.00117013
# VF_error_before         0.00128659
# env_samples         97152
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -409.32
# rwd_dense              -2.85063
# rwd_sparse             -3.8877
# stoc_pol_max         -251.048
# stoc_pol_mean        -427.861
# stoc_pol_min         -570.744
# stoc_pol_std           85.2372
# success_percentage      0
# surr_improvement        0
# t_opt                   0.344485
# time_VF                 0.153582
# time_sampling           2.36355
# ------------------  --------------
# ......................................................................................
# ITERATION : 393
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:39 2024 ]  393 -391.81 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.00145191
# VF_error_before         0.001665
# env_samples         98208
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.569
# rwd_dense              -2.60903
# rwd_sparse             -3.55823
# stoc_pol_max         -238.363
# stoc_pol_mean        -391.807
# stoc_pol_min         -576.914
# stoc_pol_std           91.6014
# success_percentage      0
# surr_improvement        0
# t_opt                   0.317349
# time_VF                 0.14708
# time_sampling           2.33632
# ------------------  --------------
# ......................................................................................
# ITERATION : 394
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:43 2024 ]  394 -405.90 -444.47 -386.20
# ------------------  --------------
# VF_error_after          0.00129916
# VF_error_before         0.00134393
# env_samples         99264
# eval_score           -444.472
# eval_success            0
# iteration             300
# kl_dist                 0
# num_samples          1056
# rollout_success         0
# running_score        -407.402
# rwd_dense              -2.70449
# rwd_sparse             -3.68841
# stoc_pol_max         -238.909
# stoc_pol_mean        -405.898
# stoc_pol_min         -594.627
# stoc_pol_std           90.8249
# success_percentage      0
# surr_improvement        0
# t_opt                   0.339559
# time_VF                 0.143764
# time_sampling           2.36677
# ------------------  --------------
# ......................................................................................
# ITERATION : 395
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:47 2024 ]  395 -414.65 -444.47 -386.20
# ------------------  ---------------
# VF_error_after           0.00185983
# VF_error_before          0.00183447
# env_samples         100320
# eval_score            -444.472
# eval_success             0
# iteration              300
# kl_dist                  0
# num_samples           1056
# rollout_success          0
# running_score         -408.126
# rwd_dense               -2.76142
# rwd_sparse              -3.76604
# stoc_pol_max          -251.109
# stoc_pol_mean         -414.648
# stoc_pol_min          -585.552
# stoc_pol_std            94.3406
# success_percentage       0
# surr_improvement         0
# t_opt                    0.293966
# time_VF                  0.13612
# time_sampling            2.22467
# ------------------  ---------------
# ......................................................................................
# ITERATION : 396
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:50 2024 ]  396 -405.04 -444.47 -386.20
# ------------------  ---------------
# VF_error_after           0.0014998
# VF_error_before          0.00170125
# env_samples         101376
# eval_score            -444.472
# eval_success             0
# iteration              300
# kl_dist                  0
# num_samples           1056
# rollout_success          0
# running_score         -407.818
# rwd_dense               -2.69736
# rwd_sparse              -3.67868
# stoc_pol_max          -230.747
# stoc_pol_mean         -405.04
# stoc_pol_min          -589.153
# stoc_pol_std            89.6002
# success_percentage       0
# surr_improvement         0
# t_opt                    0.282964
# time_VF                  0.131298
# time_sampling            2.29689
# ------------------  ---------------
# ......................................................................................
# ITERATION : 397
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:54 2024 ]  397 -412.72 -444.47 -386.20
# ------------------  ---------------
# VF_error_after           0.00155898
# VF_error_before          0.00169879
# env_samples         102432
# eval_score            -444.472
# eval_success             0
# iteration              300
# kl_dist                  0
# num_samples           1056
# rollout_success          0
# running_score         -408.308
# rwd_dense               -2.74875
# rwd_sparse              -3.74877
# stoc_pol_max          -229.495
# stoc_pol_mean         -412.715
# stoc_pol_min          -593.443
# stoc_pol_std            97.7194
# success_percentage       0
# surr_improvement         0
# t_opt                    0.364593
# time_VF                  0.17896
# time_sampling            2.28633
# ------------------  ---------------
# ......................................................................................
# ITERATION : 398
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:52:58 2024 ]  398 -397.26 -444.47 -386.20
# ------------------  ---------------
# VF_error_after           0.00144607
# VF_error_before          0.00151694
# env_samples         103488
# eval_score            -444.472
# eval_success             0
# iteration              300
# kl_dist                  0
# num_samples           1056
# rollout_success          0
# running_score         -407.203
# rwd_dense               -2.64529
# rwd_sparse              -3.60768
# stoc_pol_max          -232.241
# stoc_pol_mean         -397.262
# stoc_pol_min          -574.589
# stoc_pol_std            90.1655
# success_percentage       0
# surr_improvement         0
# t_opt                    0.291917
# time_VF                  0.139663
# time_sampling            2.55419
# ------------------  ---------------
# ......................................................................................
# ITERATION : 399
# Performing evaluation rollouts ........
# [ Sat Mar  9 15:53:01 2024 ]  399 -409.65 -444.47 -386.20
# ------------------  ---------------
# VF_error_after           0.00129298
# VF_error_before          0.0013298
# env_samples         104544
# eval_score            -444.472
# eval_success             0
# iteration              300
# kl_dist                  0
# num_samples           1056
# rollout_success          0
# running_score         -407.448
# rwd_dense               -2.72979
# rwd_sparse              -3.7229
# stoc_pol_max          -233.523
# stoc_pol_mean         -409.65
# stoc_pol_min          -577.928
# stoc_pol_std            95.4386
# success_percentage       0
# surr_improvement         0
# t_opt                    0.279577
# time_VF                  0.120871
# time_sampling            2.21093
# ------------------  ---------------
# ========================================
# Job Finished.
# ========================================
